# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (1.26.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%writefile aerial_data.yaml
# train: /content/drive/MyDrive/DSCI_511_Project/aerial-cars-dataset/images
# val: /content/drive/MyDrive/DSCI_511_Project/aerial-cars-dataset/images
# nc: 1
# names: ['car']
# Out:
# Overwriting aerial_data.yaml

# %%
# !cat aerial_data.yaml
# Out:
# train: /content/drive/MyDrive/DSCI_511_Project/aerial-cars-dataset/images
# val: /content/drive/MyDrive/DSCI_511_Project/aerial-cars-dataset/images
# nc: 1
# names: ['car']

# %%
import os

labels_dir = "/content/drive/MyDrive/DSCI_511_Project/aerial-cars-dataset/labels"
bad_files = []

for filename in os.listdir(labels_dir):
    if filename.lower().endswith('.txt'):
        file_path = os.path.join(labels_dir, filename)
        with open(file_path, "r") as f:
            lines = f.readlines()
        for line in lines:
            parts = line.strip().split()
            if parts and parts[0] != "0":
                bad_files.append((filename, line.strip()))

if bad_files:
    print("Found labels not remapped to 0:")
    for fname, line in bad_files:
        print(f"{fname}: {line}")
else:
    print("All label files have class 0.")
# Out:
# All label files have class 0.

# %% [markdown]
# ## Training The Model
# using aerial_data.yaml which contains the path for training and label files

# %%
# %cd "/content/drive/MyDrive/DSCI_511_Project/yolov5_new"
# !python train.py --img 640 --batch 16 --epochs 50 --data "/content/aerial_data.yaml" --weights yolov5s.pt
# Out:
# /content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-03-13 23:58:59.028861: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741910339.051362    3778 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741910339.057925    3778 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=, data=/content/aerial_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# /content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...'mask_interpolation': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# train: Scanning /content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/aerial-cars-dataset/labels.cache... 154 images, 1 backgrounds, 0 corrupt: 100% 154/154 [00:00<?, ?it/s]
# val: Scanning /content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/aerial-cars-dataset/labels.cache... 154 images, 1 backgrounds, 0 corrupt: 100% 154/154 [00:00<?, ?it/s]
#
# AutoAnchor: 3.26 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp14/labels.jpg...
# /content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp14
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/10 [00:00<?, ?it/s]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.51G     0.1394    0.07316          0        840        640:  10% 1/10 [00:13<02:01, 13.51s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.55G     0.1387    0.07759          0        856        640:  20% 2/10 [00:14<00:46,  5.86s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.55G     0.1375     0.0789          0        511        640:  30% 3/10 [00:15<00:27,  3.98s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.55G     0.1377    0.08077          0        848        640:  40% 4/10 [00:16<00:15,  2.54s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.55G     0.1373    0.08454          0        773        640:  50% 5/10 [00:18<00:12,  2.57s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.55G     0.1368    0.08467          0        596        640:  60% 6/10 [00:20<00:09,  2.40s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.55G     0.1367    0.08364          0        783        640:  70% 7/10 [00:22<00:06,  2.18s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.55G     0.1365    0.08324          0        749        640:  80% 8/10 [00:25<00:04,  2.39s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.03G    0.03693    0.06426          0        703        640:  70% 7/10 [00:13<00:06,  2.31s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.03G    0.03695    0.06393          0        664        640:  80% 8/10 [00:15<00:04,  2.27s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.03G    0.03645    0.06398          0        704        640:  90% 9/10 [00:18<00:02,  2.62s/it]/content/drive/.shortcut-targets-by-id/1AS-UN1w4o3QpNZIHTPMkAHdSEMNGRZzn/DSCI_511_Project/yolov5_new/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      4.03G    0.03718    0.06545          0        636        640: 100% 10/10 [00:19<00:00,  1.91s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:11<00:00,  2.31s/it]
#                    all        154       4025      0.948      0.905       0.95      0.571
#
# 50 epochs completed in 0.485 hours.
# Optimizer stripped from runs/train/exp14/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp14/weights/best.pt, 14.4MB
#
# Validating runs/train/exp14/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:10<00:00,  2.10s/it]
#                    all        154       4025      0.947      0.904       0.95      0.572
# Results saved to runs/train/exp14

# %% [markdown]
# ## Prediction using the trained model

# %%
import os
import json
import torch
import random
import cv2

# Load your custom YOLOv5 model from exp14's best.pt checkpoint
model = torch.hub.load('ultralytics/yolov5', 'custom',
                       path='/content/drive/MyDrive/DSCI_511_Project/yolov5_new/runs/train/exp14/weights/best.pt',
                       force_reload=True)
model.conf = 0.25  # Adjust confidence threshold if needed

# Define the folder containing images for inference (adjust path as needed)
image_folder = "/content/drive/MyDrive/image"

# Folder to store rendered images with detections
output_folder = "/content/drive/MyDrive/DSCI_511_Project/results/validation"
os.makedirs(output_folder, exist_ok=True)

results_list = []       # List of dicts for JSON output
detection_results = {}  # To store full result objects for visualization and saving

# Loop over images in the folder and run inference
for filename in os.listdir(image_folder):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(image_folder, filename)
        try:
            results = model(image_path)
        except FileNotFoundError:
            print(f"File not found, skipping: {filename}")
            continue
        detections = results.xyxy[0]  # [x1, y1, x2, y2, conf, class]
        car_count = detections.shape[0]  # each row corresponds to a detection
        results_list.append({
            "store_code": filename,
            "no of cars": int(car_count)
        })
        detection_results[filename] = results

        # Render the image with bounding boxes and save it
        rendered_imgs = results.render()  # returns list of rendered images
        for i, img in enumerate(rendered_imgs):
            # Construct output filename
            save_filename = f"validation_{filename}" if len(rendered_imgs)==1 else f"validation_{i}_{filename}"
            save_path = os.path.join(output_folder, save_filename)
            cv2.imwrite(save_path, img)

# Define output JSON path and save the results
json_path = "/content/drive/MyDrive/DSCI_511_Project/results/car_counts.json"
with open(json_path, "w") as f:
    json.dump(results_list, f, indent=4)

FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Results JSON saved to: /content/drive/MyDrive/DSCI_511_Project/results/car_counts.json
# Rendered images saved to: /content/drive/MyDrive/DSCI_511_Project/results/validation

# %% [markdown]
# ## Creating the Final JSON

# %%
import json

# Helper function to load a JSON file.
# It first attempts to load the file as a JSON array.
# If that fails (e.g. because the file is in NDJSON format), it loads line‑by‑line.
def load_json_file(filepath):
    try:
        with open(filepath, "r") as f:
            data = json.load(f)
        return data
    except json.JSONDecodeError:
        data = []
        with open(filepath, "r") as f:
            for line in f:
                line = line.strip()
                if line:
                    try:
                        data.append(json.loads(line))
                    except json.JSONDecodeError as e:
                        print(f"Error decoding a line in {filepath}: {e}")
        return data

# Define file paths
records_path = "/content/drive/MyDrive/records.json"
car_results_path = "/content/drive/MyDrive/DSCI_511_Project/results/car_counts.json"
final_results_path = "/content/drive/MyDrive/DSCI_511_Project/results/final_results.json"

# Load records.json
records_data = load_json_file(records_path)
print(f"Loaded {len(records_data)} records from {records_path}")

# Load car_counts.json
car_results_data = load_json_file(car_results_path)
print(f"Loaded {len(car_results_data)} entries from {car_results_path}")

# Remove duplicate place_ids from records.json (keeping the first occurrence)
unique_records = {}
for record in records_data:
    place_id = record["place_id"]
    if place_id not in unique_records:
        unique_records[place_id] = record
records_data_unique = list(unique_records.values())
print(f"After deduplication, {len(records_data_unique)} unique records remain.")

# Build a mapping from car_counts.json: strip ".png" from store_code and use the correct key "no of cars"
car_count_map = {}
for car in car_results_data:
    store_code = car["store_code"]
    if store_code.endswith(".png"):
        store_code = store_code[:-4]  # remove ".png"
    car_count_map[store_code] = car.get("no of cars", 0)

records_ids = set(unique_records.keys())
car_ids = set(car_count_map.keys())
print(f"Unique place_ids in records: {len(records_ids)}")
print(f"Unique store_codes in car_counts (after stripping .png): {len(car_ids)}")

mismatches_in_records = records_ids - car_ids
mismatches_in_car_results = car_ids - records_ids

if mismatches_in_records or mismatches_in_car_results:
    print("Mismatches found!")
    if mismatches_in_records:
        print("place_ids in records but not in car_counts:")
        print(mismatches_in_records)
    if mismatches_in_car_results:
        print("store_codes in car_counts but not in records:")
        print(mismatches_in_car_results)
else:
    print("All place_ids and store_codes match. Proceeding with merging...")

# Merge car counts into records
final_results = []
for record in records_data_unique:
    place_id = record["place_id"]
    # Set the no_of_cars value from car_count_map (will be non-zero if the mapping is correct)
    record["no_of_cars"] = car_count_map.get(place_id, 0)
    final_results.append(record)

# Save the merged results
with open(final_results_path, "w") as f:
    json.dump(final_results, f, indent=4)
print(f"Final results saved to {final_results_path}")
# Out:
# Loaded 1998 records from /content/drive/MyDrive/records.json
# Loaded 1791 entries from /content/drive/MyDrive/DSCI_511_Project/results/car_counts.json
# After deduplication, 1791 unique records remain.
# Unique place_ids in records: 1791
# Unique store_codes in car_counts (after stripping .png): 1791
# All place_ids and store_codes match. Proceeding with merging...
# Final results saved to /content/drive/MyDrive/DSCI_511_Project/results/final_results.json

# %%
import json
import pandas as pd

# Load the final results JSON
with open(final_results_path, "r") as f:
    final_results = json.load(f)

# Print the final JSON data (formatted)
print(json.dumps(final_results, indent=4))

# Convert the JSON data to a pandas DataFrame and print the first few rows
df = pd.DataFrame(final_results)
df.head(20)
# Out:
# [
#     {
#         "address": "Parking lot, Water St, Clinton, NJ 08809, United States",
#         "location": {
#             "lat": 40.6387329,
#             "lng": -74.9117948
#         },
#         "name": "Municipal Lot",
#         "place_id": "ChIJR8IPtAWLw4kROvacIJ6onxQ",
#         "county": "Clinton County",
#         "no_of_cars": 7
#     },
#     {
#         "address": "NJ-31, Clinton, NJ 08809, United States",
#         "location": {
#             "lat": 40.6392178,
#             "lng": -74.8938984
#         },
#         "name": "Clinton Park & Ride",
#         "place_id": "ChIJR8t_I3eLw4kRmJNbQ9Z1a4Q",
#         "county": "Clinton County",
#         "no_of_cars": 15
#     },
#     {
#         "address": "234 Main St, Hurleyville, NY 12747, United States",
#         "location": {
#             "lat": 41.7371061,
#             "lng": -74.6734227
#         },
#         "name": "Morgan Outdoors",
#         "place_id": "ChIJyZKFEAiZ3IkR0Y2NXWcrohQ",
#         "county": "Sullivan County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "325 W Freedom Ave, Burnham, PA 17009, United States",
#         "location": {
#             "lat": 40.6304321,
#             "lng": -77.573883
#         },
#         "name": "Mifflin County Commons",
#         "place_id": "ChIJ18GSIGK1zokROnth9b2MgbY",
#         "county": "Mifflin County",
#         "no_of_cars": 54
#     },
#     {
#         "address": "842 W 4th St, Lewistown, PA 17044, United States",
#         "location": {
#             "lat": 40.591275,
#             "lng": -77.5948901
#         },
#         "name": "Dan Pierce Outdoor Shop",
#         "place_id": "ChIJ53wMosJKyYkRSUmITaXRot4",
#         "county": "Mifflin County",
#         "no_of_cars": 19
#     },
#     {
#         "address": "7345 PA-655, Reedsville, PA 17084, United States",
#         "location": {
#             "lat": 40.6587312,
#             "lng": -77.622937
#         },
#         "name": "Hostetler Country Market",
#         "place_id": "ChIJQ-X_VUS1zokRenmiLUAVIH8",
#         "county": "Mifflin County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "34 Morgan Dr, Mcveytown, PA 17051, United States",
#         "location": {
#             "lat": 40.4778482,
#             "lng": -77.77877459999999
#         },
#         "name": "Nolt's Farm & Garden Inc",
#         "place_id": "ChIJ_ePF83BQyYkRFrYOb2XmxT8",
#         "county": "Mifflin County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "64 Forest Edge Ln, Lewistown, PA 17044, United States",
#         "location": {
#             "lat": 40.6364735,
#             "lng": -77.4779076
#         },
#         "name": "Carolus Trapping Supply",
#         "place_id": "ChIJYT5tIK_LzokRDBwZ5PP8S5Q",
#         "county": "Mifflin County",
#         "no_of_cars": 0
#     },
#     {
#         "address": "5867 US-522, McClure, PA 17841, United States",
#         "location": {
#             "lat": 40.6800825,
#             "lng": -77.4116385
#         },
#         "name": "Point Store",
#         "place_id": "ChIJ14epjXrOzokRArbqb-AIJ7w",
#         "county": "Mifflin County",
#         "no_of_cars": 7
#     },
#     {
#         "address": "150 Helen St, Lewistown, PA 17044, United States",
#         "location": {
#             "lat": 40.5883966,
#             "lng": -77.5798216
#         },
#         "name": "Lewistown Station",
#         "place_id": "ChIJkY-F5ZVKyYkRCwmoQR7oFN8",
#         "county": "Mifflin County",
#         "no_of_cars": 9
#     },
#     {
#         "address": "20 Shaw Ave #6, Lewistown, PA 17044, United States",
#         "location": {
#             "lat": 40.60090599999999,
#             "lng": -77.56812289999999
#         },
#         "name": "Park Way Store",
#         "place_id": "ChIJned00a5KyYkRUfRFk2sUpbw",
#         "county": "Mifflin County",
#         "no_of_cars": 10
#     },
#     {
#         "address": "100 Cherry St, Lewistown, PA 17044, United States",
#         "location": {
#             "lat": 40.5979522,
#             "lng": -77.56532829999999
#         },
#         "name": "Rec Park",
#         "place_id": "ChIJy9kaLUVLyYkRXf6fRMmteJo",
#         "county": "Mifflin County",
#         "no_of_cars": 0
#     },
#     {
#         "address": "1146 Honey Creek Rd, Reedsville, PA 17084, United States",
#         "location": {
#             "lat": 40.6854246,
#             "lng": -77.55803039999999
#         },
#         "name": "The Reedsville Creamery - Farm Stand",
#         "place_id": "ChIJ7U17ta_LzokRObFoxlW_Fo8",
#         "county": "Mifflin County",
#         "no_of_cars": 2
#     },
#     {
#         "address": "100 Classic Car Dr, Reedsville, PA 17084, United States",
#         "location": {
#             "lat": 40.6971777,
#             "lng": -77.5936251
#         },
#         "name": "Top Flight Automotive",
#         "place_id": "ChIJ75HUcia3zokRdlbGFkCCP6k",
#         "county": "Mifflin County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "10180 U.S. 522 S, Lewistown, PA 17044, United States",
#         "location": {
#             "lat": 40.5814965,
#             "lng": -77.61158999999999
#         },
#         "name": "Walmart Supercenter",
#         "place_id": "ChIJg5ydPwNLyYkRwwO8lON2drA",
#         "county": "Mifflin County",
#         "no_of_cars": 4
#     },
#     {
#         "address": "S Juniata St, Lewistown, PA 17044, United States",
#         "location": {
#             "lat": 40.5954389,
#             "lng": -77.5759211
#         },
#         "name": "Parking Lot",
#         "place_id": "ChIJTe8EdbtKyYkRPnu0P_k0I1Y",
#         "county": "Mifflin County",
#         "no_of_cars": 11
#     },
#     {
#         "address": "100 Cherry St, Lewistown, PA 17044, United States",
#         "location": {
#             "lat": 40.5978752,
#             "lng": -77.5662241
#         },
#         "name": "Rec Park Swimming Pool",
#         "place_id": "ChIJJ0MAoqhKyYkRWtZgNXaOsC8",
#         "county": "Mifflin County",
#         "no_of_cars": 2
#     },
#     {
#         "address": "900 Green Ln, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.6826058,
#             "lng": -74.23897819999999
#         },
#         "name": "SP+ Parking",
#         "place_id": "ChIJWaba00Ktw4kRCQduFc-lLNw",
#         "county": "Union County",
#         "no_of_cars": 30
#     },
#     {
#         "address": "Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.6922395,
#             "lng": -74.28800369999999
#         },
#         "name": "Parking lot",
#         "place_id": "ChIJU2ZdOQCtw4kRdDNJzko5dtM",
#         "county": "Union County",
#         "no_of_cars": 57
#     },
#     {
#         "address": "Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.6893969,
#             "lng": -74.3027101
#         },
#         "name": "Parking",
#         "place_id": "ChIJI2evNyWtw4kRYnQXkuAJIbg",
#         "county": "Union County",
#         "no_of_cars": 12
#     },
#     {
#         "address": "Stowe St, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.6979754,
#             "lng": -74.2702008
#         },
#         "name": "Township of Union Municipal Parking Lot Number 8",
#         "place_id": "ChIJ____jKGtw4kR4-h0UJtCVX8",
#         "county": "Union County",
#         "no_of_cars": 26
#     },
#     {
#         "address": "930 Springfield Rd, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.6876152,
#             "lng": -74.3031232
#         },
#         "name": "Parking",
#         "place_id": "ChIJtXynN9atw4kRAUv0Jxt9glw",
#         "county": "Union County",
#         "no_of_cars": 23
#     },
#     {
#         "address": "2700A US-22, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.6870208,
#             "lng": -74.3107107
#         },
#         "name": "DICK'S Sporting Goods",
#         "place_id": "ChIJqzvBaP6tw4kRxDkwUxhQp8M",
#         "county": "Union County",
#         "no_of_cars": 16
#     },
#     {
#         "address": "4 S Union Ave, Cranford, NJ 07016, United States",
#         "location": {
#             "lat": 40.6548521,
#             "lng": -74.3053533
#         },
#         "name": "Municipal Parking Garage",
#         "place_id": "ChIJ4670KSSyw4kRb_tkNp_WZhs",
#         "county": "Union County",
#         "no_of_cars": 6
#     },
#     {
#         "address": "2365a US-22, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.69107169999999,
#             "lng": -74.2939384
#         },
#         "name": "Lidl Parking",
#         "place_id": "ChIJtcaBZh2tw4kRXpQhI0X9GuE",
#         "county": "Union County",
#         "no_of_cars": 27
#     },
#     {
#         "address": "2661 Morris Ave, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.7049609,
#             "lng": -74.29406759999999
#         },
#         "name": "2nd Ave Thrift Superstore - Union, NJ",
#         "place_id": "ChIJySQsh8itw4kRVllwCVZSUEI",
#         "county": "Union County",
#         "no_of_cars": 8
#     },
#     {
#         "address": "117-125 Union St, Elizabeth, NJ 07202, United States",
#         "location": {
#             "lat": 40.6660808,
#             "lng": -74.2168245
#         },
#         "name": "117-125 Union St Garage",
#         "place_id": "ChIJa72Gw1RNwokR-TqQi5bQR5I",
#         "county": "Union County",
#         "no_of_cars": 11
#     },
#     {
#         "address": "4 S Union Ave, Cranford, NJ 07016, United States",
#         "location": {
#             "lat": 40.6548159,
#             "lng": -74.3058418
#         },
#         "name": "4 S Union Ave Garage",
#         "place_id": "ChIJlSOKKSSyw4kRx4C1N7H12C4",
#         "county": "Union County",
#         "no_of_cars": 10
#     },
#     {
#         "address": "930 Springfield Rd, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.6878918,
#             "lng": -74.2999206
#         },
#         "name": "Parking",
#         "place_id": "ChIJ2UhlSbatw4kR8CileIEXp-U",
#         "county": "Union County",
#         "no_of_cars": 30
#     },
#     {
#         "address": "831 Springfield Ave, Cranford, NJ 07016, United States",
#         "location": {
#             "lat": 40.6660729,
#             "lng": -74.3168123
#         },
#         "name": "Dreyer Farms",
#         "place_id": "ChIJeXRX9PSxw4kRs44V67oucwM",
#         "county": "Union County",
#         "no_of_cars": 9
#     },
#     {
#         "address": "254 Pearl St, Bridgeton, NJ 08302, United States",
#         "location": {
#             "lat": 39.435917,
#             "lng": -75.2289365
#         },
#         "name": "254-260 Union Ave Parking",
#         "place_id": "ChIJO-AHS1VNwokRTezydH2tdts",
#         "county": "Union County",
#         "no_of_cars": 18
#     },
#     {
#         "address": "Elizabeth, NJ 07202, United States",
#         "location": {
#             "lat": 40.6650201,
#             "lng": -74.2164769
#         },
#         "name": "J.Christian Bollwage Parking Garage",
#         "place_id": "ChIJs-jPl1RNwokRH18O7iS83_Q",
#         "county": "Union County",
#         "no_of_cars": 17
#     },
#     {
#         "address": "Jersey Gardens Blvd, Elizabeth, NJ 07201, United States",
#         "location": {
#             "lat": 40.6604232,
#             "lng": -74.1731337
#         },
#         "name": "Garage Clothing",
#         "place_id": "ChIJ8ydAxFhNwokRx5I0jjXVCq8",
#         "county": "Union County",
#         "no_of_cars": 4
#     },
#     {
#         "address": "2438 US-22 E, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.6893692,
#             "lng": -74.2970352
#         },
#         "name": "Harbor Freight",
#         "place_id": "ChIJ1VsQ2IbLNIgRoiPi_Zq1MPg",
#         "county": "Union County",
#         "no_of_cars": 35
#     },
#     {
#         "address": "4001 Walnut St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9544225,
#             "lng": -75.2028042
#         },
#         "name": "ACME Markets",
#         "place_id": "ChIJC2jiyavHxokRmu-rm7lbZB0",
#         "county": "Union County",
#         "no_of_cars": 14
#     },
#     {
#         "address": "1774c Burnet Ave, Union, NJ 07083, United States",
#         "location": {
#             "lat": 40.7156483,
#             "lng": -74.2689303
#         },
#         "name": "Parking lot",
#         "place_id": "ChIJhXDOWQCtw4kRjOtCO0RYJuM",
#         "county": "Union County",
#         "no_of_cars": 16
#     },
#     {
#         "address": "516 35th St, Union City, NJ 07087, United States",
#         "location": {
#             "lat": 40.7742155,
#             "lng": -74.0288727
#         },
#         "name": "UNION CITY PARKING GARAGE",
#         "place_id": "ChIJg6PmcidYwokRjsw4GtNLplg",
#         "county": "Union County",
#         "no_of_cars": 24
#     },
#     {
#         "address": "3101 Market St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.955624,
#             "lng": -75.18561059999999
#         },
#         "name": "Parkway Parking - 3101 Market Street",
#         "place_id": "ChIJgXhPWVzHxokR210hhVRE3cs",
#         "county": "Philadelphia County",
#         "no_of_cars": 14
#     },
#     {
#         "address": "45 N 10th St, Philadelphia, PA 19107, United States",
#         "location": {
#             "lat": 39.9528277,
#             "lng": -75.1563118
#         },
#         "name": "The Autopark at The Fashion District",
#         "place_id": "ChIJEfUQ5SnGxokRmSPclKa6TIg",
#         "county": "Philadelphia County",
#         "no_of_cars": 27
#     },
#     {
#         "address": "1540 Vine St, Philadelphia, PA 19102, United States",
#         "location": {
#             "lat": 39.9573755,
#             "lng": -75.1650667
#         },
#         "name": "Gateway Parking Garage",
#         "place_id": "ChIJhW-tdi3GxokRzs9cJIjeAVU",
#         "county": "Philadelphia County",
#         "no_of_cars": 148
#     },
#     {
#         "address": "1627-45 Pine St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9466049,
#             "lng": -75.1694998
#         },
#         "name": "E-Z Park, Inc.",
#         "place_id": "ChIJCT7NozvGxokR4uopEiALmTE",
#         "county": "Philadelphia County",
#         "no_of_cars": 50
#     },
#     {
#         "address": "2929 Arch St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9573759,
#             "lng": -75.1816783
#         },
#         "name": "SP+ Parking",
#         "place_id": "ChIJCSj8v0vGxokRtJHhnJl21ZY",
#         "county": "Philadelphia County",
#         "no_of_cars": 109
#     },
#     {
#         "address": "2101 Chestnut St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9524438,
#             "lng": -75.17575599999999
#         },
#         "name": "E-Z Park, Inc. - 36 S 21st (at Chestnut)",
#         "place_id": "ChIJwYXmujfGxokRssQn2jqwNMA",
#         "county": "Philadelphia County",
#         "no_of_cars": 31
#     },
#     {
#         "address": "2102 Sansom St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9513043,
#             "lng": -75.1758498
#         },
#         "name": "Patriot Parking Inc",
#         "place_id": "ChIJgwhBTSfGxokROrD0gqawsQI",
#         "county": "Philadelphia County",
#         "no_of_cars": 21
#     },
#     {
#         "address": "200 S 24th St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.95092460000001,
#             "lng": -75.17968429999999
#         },
#         "name": "Walnut Bridge Parking & Storage",
#         "place_id": "ChIJYX8C30fGxokR-8GwDC3rjRg",
#         "county": "Philadelphia County",
#         "no_of_cars": 26
#     },
#     {
#         "address": "3601 Market St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9569169,
#             "lng": -75.194636
#         },
#         "name": "3601 Market St Garage",
#         "place_id": "ChIJUYcYOlHGxokRFF7ob9AWLlo",
#         "county": "Philadelphia County",
#         "no_of_cars": 16
#     },
#     {
#         "address": "2955 Market St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9557501,
#             "lng": -75.1819889
#         },
#         "name": "SP+ Parking",
#         "place_id": "ChIJpUjU_1LHxokRVA4jbfqXuHc",
#         "county": "Philadelphia County",
#         "no_of_cars": 9
#     },
#     {
#         "address": "3731 Walnut St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9537193,
#             "lng": -75.1978486
#         },
#         "name": "Walnut 38",
#         "place_id": "ChIJ9cLMfVfGxokRyLwAw0qiCeY",
#         "county": "Philadelphia County",
#         "no_of_cars": 29
#     },
#     {
#         "address": "3401 Chestnut St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9548144,
#             "lng": -75.1920076
#         },
#         "name": "GIANT Heirloom Market",
#         "place_id": "ChIJkQwr5t_HxokRauOW9yfKaBE",
#         "county": "Philadelphia County",
#         "no_of_cars": 35
#     },
#     {
#         "address": "3816 Market St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9563585,
#             "lng": -75.1989771
#         },
#         "name": "3816 Market St Parking",
#         "place_id": "ChIJxzm6UlbGxokRY_L3j3GCHJc",
#         "county": "Philadelphia County",
#         "no_of_cars": 117
#     },
#     {
#         "address": "1700 Market St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9529321,
#             "lng": -75.1697113
#         },
#         "name": "1700 Market Garage",
#         "place_id": "ChIJ0x5QojHGxokR_rxrh7CHlqw",
#         "county": "Philadelphia County",
#         "no_of_cars": 22
#     },
#     {
#         "address": "2979 Arch St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.957068,
#             "lng": -75.1817272
#         },
#         "name": "Cira Parking",
#         "place_id": "ChIJ5SWT20vGxokRvAMh7IED3a4",
#         "county": "Philadelphia County",
#         "no_of_cars": 78
#     },
#     {
#         "address": "303 Bainbridge St, Philadelphia, PA 19147, United States",
#         "location": {
#             "lat": 39.9412253,
#             "lng": -75.1501056
#         },
#         "name": "E-Z Park",
#         "place_id": "ChIJx4ZRN5nIxokRd0SIxZATHqg",
#         "county": "Philadelphia County",
#         "no_of_cars": 76
#     },
#     {
#         "address": "Philadelphia Market Street, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.95495680000001,
#             "lng": -75.17775379999999
#         },
#         "name": "Philadelphia Market Street Garage",
#         "place_id": "ChIJH9p_4EnGxokRaqPiopjsmFk",
#         "county": "Philadelphia County",
#         "no_of_cars": 65
#     },
#     {
#         "address": "Philadelphia, PA 19131, United States",
#         "location": {
#             "lat": 39.9928039,
#             "lng": -75.19444229999999
#         },
#         "name": "Public Parking Lot",
#         "place_id": "ChIJCS2o6VTHxokRo4DITM2nfjc",
#         "county": "Philadelphia County",
#         "no_of_cars": 1
#     },
#     {
#         "address": "2401 Walnut St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9515389,
#             "lng": -75.1798003
#         },
#         "name": "Parkway Parking - 2401 Walnut Street",
#         "place_id": "ChIJOeovcEjGxokRs99puhlKx-Q",
#         "county": "Philadelphia County",
#         "no_of_cars": 50
#     },
#     {
#         "address": "1912 Walnut St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.950314,
#             "lng": -75.1737349
#         },
#         "name": "Parkway Parking - 20th & Walnut",
#         "place_id": "ChIJcTWd4DnGxokRsgNmyke_Qbs",
#         "county": "Philadelphia County",
#         "no_of_cars": 60
#     },
#     {
#         "address": "1924 Chestnut St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.951729,
#             "lng": -75.17312319999999
#         },
#         "name": "E-Z Park, Inc.",
#         "place_id": "ChIJ95_M2jDGxokRXkT9xt0o3n0",
#         "county": "Philadelphia County",
#         "no_of_cars": 43
#     },
#     {
#         "address": "across Belmont Stables, Philadelphia, PA 19131, United States",
#         "location": {
#             "lat": 39.9891651,
#             "lng": -75.2027226
#         },
#         "name": "Public Parking Lot",
#         "place_id": "ChIJKTSU2APHxokR1pBHKI6ddak",
#         "county": "Philadelphia County",
#         "no_of_cars": 0
#     },
#     {
#         "address": "4629 Lancaster Ave, Philadelphia, PA 19131, United States",
#         "location": {
#             "lat": 39.97089920000001,
#             "lng": -75.2146324
#         },
#         "name": "Open Lot",
#         "place_id": "ChIJRRfLYRvHxokRDXwRcM1_pJo",
#         "county": "Philadelphia County",
#         "no_of_cars": 12
#     },
#     {
#         "address": "1327 Locust St, Philadelphia, PA 19107, United States",
#         "location": {
#             "lat": 39.9486196,
#             "lng": -75.1633045
#         },
#         "name": "Juniper & Locust iParkit Garage",
#         "place_id": "ChIJb82odSXGxokRvId8yp8Y6J4",
#         "county": "Philadelphia County",
#         "no_of_cars": 70
#     },
#     {
#         "address": "132 S 32nd St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9532122,
#             "lng": -75.1882538
#         },
#         "name": "Lot A",
#         "place_id": "ChIJJez77E_GxokRHFgUqnJ7XTQ",
#         "county": "Philadelphia County",
#         "no_of_cars": 4
#     },
#     {
#         "address": "2301 Race St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9584302,
#             "lng": -75.1772469
#         },
#         "name": "Edgewater Garage",
#         "place_id": "ChIJE74AmzXGxokRnHYkry_L7Po",
#         "county": "Philadelphia County",
#         "no_of_cars": 35
#     },
#     {
#         "address": "36 S 19th St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9526505,
#             "lng": -75.1721816
#         },
#         "name": "SP+ Parking",
#         "place_id": "ChIJdVOG1DDGxokR5NICUopl4b8",
#         "county": "Philadelphia County",
#         "no_of_cars": 17
#     },
#     {
#         "address": "Philadelphia, PA 19131, United States",
#         "location": {
#             "lat": 40.0008726,
#             "lng": -75.1925962
#         },
#         "name": "Public Parking Lot",
#         "place_id": "ChIJd6LRbr7HxokRgMgWvC3YfH8",
#         "county": "Philadelphia County",
#         "no_of_cars": 0
#     },
#     {
#         "address": "225 N 38th St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.958365,
#             "lng": -75.1974554
#         },
#         "name": "LAZ Parking - 38th & Market",
#         "place_id": "ChIJ-_JDX4XHxokRUO5NFfsOfNc",
#         "county": "Philadelphia County",
#         "no_of_cars": 57
#     },
#     {
#         "address": "926 Carpenter St, Philadelphia, PA 19147, United States",
#         "location": {
#             "lat": 39.9376085,
#             "lng": -75.15908689999999
#         },
#         "name": "Italian Market Parking",
#         "place_id": "ChIJgYCAQR_GxokRphnG60J8kNM",
#         "county": "Philadelphia County",
#         "no_of_cars": 50
#     },
#     {
#         "address": "1919 Market St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9539164,
#             "lng": -75.17269089999999
#         },
#         "name": "1919 Market St. Garage",
#         "place_id": "ChIJfXSlQHHHxokRqkoQlBs3WAo",
#         "county": "Philadelphia County",
#         "no_of_cars": 19
#     },
#     {
#         "address": "1835 Market St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9538081,
#             "lng": -75.17117139999999
#         },
#         "name": "Parkway Parking - 1835 Market Street",
#         "place_id": "ChIJx3EGOTHGxokR3rVa480Q_kg",
#         "county": "Philadelphia County",
#         "no_of_cars": 9
#     },
#     {
#         "address": "1845 Walnut St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9506933,
#             "lng": -75.1715016
#         },
#         "name": "Philadelphia parking",
#         "place_id": "ChIJ_3pZW8nHxokRaC0C-DvmyGk",
#         "county": "Philadelphia County",
#         "no_of_cars": 38
#     },
#     {
#         "address": "1231 Summer St, Philadelphia, PA 19107, United States",
#         "location": {
#             "lat": 39.9571616,
#             "lng": -75.1595432
#         },
#         "name": "E-Z Park, Inc.",
#         "place_id": "ChIJKdEj9izGxokRnnYblV5LDSY",
#         "county": "Philadelphia County",
#         "no_of_cars": 128
#     },
#     {
#         "address": "1506 Summer St, Philadelphia, PA 19102, United States",
#         "location": {
#             "lat": 39.9574198,
#             "lng": -75.1644724
#         },
#         "name": "Philadelphia Gateway - Public Parking Lot",
#         "place_id": "ChIJezUZEPfHxokRNu2Z5Euo17Y",
#         "county": "Philadelphia County",
#         "no_of_cars": 118
#     },
#     {
#         "address": "1740 South St, Philadelphia, PA 19146, United States",
#         "location": {
#             "lat": 39.9443027,
#             "lng": -75.17147229999999
#         },
#         "name": "South Street Parking Garage",
#         "place_id": "ChIJiW-HGzzGxokR9Uz8xYJu-Xw",
#         "county": "Philadelphia County",
#         "no_of_cars": 38
#     },
#     {
#         "address": "2101 Chestnut St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9524508,
#             "lng": -75.1758244
#         },
#         "name": "Parkway Garage",
#         "place_id": "ChIJRbIeja_HxokRJ2FWBwvrHmQ",
#         "county": "Philadelphia County",
#         "no_of_cars": 35
#     },
#     {
#         "address": "2005 Market St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9541826,
#             "lng": -75.1748843
#         },
#         "name": "Commerce Square Parking Garage",
#         "place_id": "ChIJk2dsHA3HxokRmPXmkEkjTrM",
#         "county": "Philadelphia County",
#         "no_of_cars": 23
#     },
#     {
#         "address": "1901 Callowhill St, Philadelphia, PA 19130, United States",
#         "location": {
#             "lat": 39.9604814,
#             "lng": -75.1706313
#         },
#         "name": "19th & Callowhill St Parking Lot",
#         "place_id": "ChIJjxssz8zHxokRcWOO7Na4WeE",
#         "county": "Philadelphia County",
#         "no_of_cars": 90
#     },
#     {
#         "address": "859 N Broad St, Philadelphia, PA 19123, United States",
#         "location": {
#             "lat": 39.9699472,
#             "lng": -75.1594198
#         },
#         "name": "Target Park USA",
#         "place_id": "ChIJ9z0faVrHxokRo6snAJdqobg",
#         "county": "Philadelphia County",
#         "no_of_cars": 30
#     },
#     {
#         "address": "107 S 10th St, Philadelphia, PA 19107, United States",
#         "location": {
#             "lat": 39.9497804,
#             "lng": -75.157034
#         },
#         "name": "Jefferson iParkit Garage",
#         "place_id": "ChIJb82odSXGxokR6CFahPGoUrI",
#         "county": "Philadelphia County",
#         "no_of_cars": 45
#     },
#     {
#         "address": "5 N 21st St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9541692,
#             "lng": -75.1749157
#         },
#         "name": "Bex Parking Garage - Commerce Square",
#         "place_id": "ChIJpTw69DbGxokRiS3_dSMAre4",
#         "county": "Philadelphia County",
#         "no_of_cars": 23
#     },
#     {
#         "address": "220n S 15th St, Philadelphia, PA 19102, United States",
#         "location": {
#             "lat": 39.9489724,
#             "lng": -75.16650849999999
#         },
#         "name": "Park America",
#         "place_id": "ChIJOxKK_y_GxokRZ3glATv8H2s",
#         "county": "Philadelphia County",
#         "no_of_cars": 34
#     },
#     {
#         "address": "14-18 S 10th St, Philadelphia, PA 19107, United States",
#         "location": {
#             "lat": 39.9507926,
#             "lng": -75.1573691
#         },
#         "name": "AutoPark at Jefferson",
#         "place_id": "ChIJaVBEnRvGxokR7CbTaUM-PMk",
#         "county": "Philadelphia County",
#         "no_of_cars": 39
#     },
#     {
#         "address": "1845 Walnut St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.95036109999999,
#             "lng": -75.17140309999999
#         },
#         "name": "Parkway Parking - 1845 Walnut Street",
#         "place_id": "ChIJLcKnqTDGxokRrGAJbQBh1tA",
#         "county": "Philadelphia County",
#         "no_of_cars": 24
#     },
#     {
#         "address": "221 S 11th St, Philadelphia, PA 19107, United States",
#         "location": {
#             "lat": 39.94796669999999,
#             "lng": -75.1590659
#         },
#         "name": "Hamilton iParkit Garage",
#         "place_id": "ChIJLZz6FibGxokRC2U3Da23434",
#         "county": "Philadelphia County",
#         "no_of_cars": 15
#     },
#     {
#         "address": "1800 Market St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9531076,
#             "lng": -75.1705468
#         },
#         "name": "Sonesta iParkit Garage",
#         "place_id": "ChIJb82odSXGxokRV7HsUYkw8V8",
#         "county": "Philadelphia County",
#         "no_of_cars": 19
#     },
#     {
#         "address": "3901 Market St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9574429,
#             "lng": -75.2007276
#         },
#         "name": "Central Parking",
#         "place_id": "ChIJFdpjT1bGxokR6iH0DVYQ6i4",
#         "county": "Philadelphia County",
#         "no_of_cars": 25
#     },
#     {
#         "address": "Stone Gazebo, Avenue of the Republic, Philadelphia, PA 19131, United States",
#         "location": {
#             "lat": 39.982665,
#             "lng": -75.218885
#         },
#         "name": "Fairmount Park Free Parking Lot 2",
#         "place_id": "ChIJCUWVZCTHxokRgdNsqgVbxsA",
#         "county": "Philadelphia County",
#         "no_of_cars": 0
#     },
#     {
#         "address": "1717 Arch St, Philadelphia, PA 19103, United States",
#         "location": {
#             "lat": 39.9553161,
#             "lng": -75.1692751
#         },
#         "name": "Three Logan Square Parking Garage",
#         "place_id": "ChIJz5DF3A_HxokRRISvvklWVp4",
#         "county": "Philadelphia County",
#         "no_of_cars": 13
#     },
#     {
#         "address": "1317 Spring Garden St, Philadelphia, PA 19123, United States",
#         "location": {
#             "lat": 39.9623447,
#             "lng": -75.15994189999999
#         },
#         "name": "1317 Spring Garden St Parking",
#         "place_id": "ChIJG4iZc9THxokRBfvxnn4I5S8",
#         "county": "Philadelphia County",
#         "no_of_cars": 69
#     },
#     {
#         "address": "56 N 39th St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9573525,
#             "lng": -75.2000079
#         },
#         "name": "3901 Market St Parking",
#         "place_id": "ChIJb2QwOVbGxokRVGxsTyiEvh4",
#         "county": "Philadelphia County",
#         "no_of_cars": 53
#     },
#     {
#         "address": "9731 S 11th St, Philadelphia, PA 19148, United States",
#         "location": {
#             "lat": 39.899756,
#             "lng": -75.1720361
#         },
#         "name": "Lot D",
#         "place_id": "ChIJzfkJrJTFxokROzL2c8z1lso",
#         "county": "Philadelphia County",
#         "no_of_cars": 2
#     },
#     {
#         "address": "114 S 15th St, Philadelphia, PA 19106, United States",
#         "location": {
#             "lat": 39.9504027,
#             "lng": -75.1660514
#         },
#         "name": "15th & Sansom iParkit Garage",
#         "place_id": "ChIJb82odSXGxokRi6QNAreKLsg",
#         "county": "Philadelphia County",
#         "no_of_cars": 29
#     },
#     {
#         "address": "530 S 2nd St, Philadelphia, PA 19147, United States",
#         "location": {
#             "lat": 39.9415346,
#             "lng": -75.1459524
#         },
#         "name": "Target Park USA",
#         "place_id": "ChIJbzBcE0PJxokRPGL4jMSmsYE",
#         "county": "Philadelphia County",
#         "no_of_cars": 48
#     },
#     {
#         "address": "1308 Sansom St, Philadelphia, PA 19107, United States",
#         "location": {
#             "lat": 39.9497627,
#             "lng": -75.1624957
#         },
#         "name": "Patriot Parking",
#         "place_id": "ChIJP90lZS_GxokRil9Pf_G7uKI",
#         "county": "Philadelphia County",
#         "no_of_cars": 7
#     },
#     {
#         "address": "330 S Broad St, Philadelphia, PA 19102, United States",
#         "location": {
#             "lat": 39.9467886,
#             "lng": -75.1649841
#         },
#         "name": "Parkway Parking - Kimmel Center (300 S Broad)",
#         "place_id": "ChIJSVc1wSTGxokRsV6c5ZcwMH0",
#         "county": "Philadelphia County",
#         "no_of_cars": 29
#     },
#     {
#         "address": "3661 Walnut St, Philadelphia, PA 19104, United States",
#         "location": {
#             "lat": 39.9535614,
#             "lng": -75.1965008
#         },
#         "name": "Hello World Modern Mercantile",
#         "place_id": "ChIJK3fcPSTGxokRSdIYDHyNuCE",
#         "county": "Philadelphia County",
#         "no_of_cars": 37
#     },
#     {
#         "address": "1012 E Passyunk Ave, Philadelphia, PA 19147, United States",
#         "location": {
#             "lat": 39.9365318,
#             "lng": -75.15595859999999
#         },
#         "name": "Municipal Parking Lot",
#         "place_id": "ChIJc5laxx_GxokRAuxWwPxRxiM",
#         "county": "Philadelphia County",
#         "no_of_cars": 82
#     },
#     {
#         "address": "44 S 16th St, Philadelphia, PA 19102, United States",
#         "location": {
#             "lat": 39.9516934,
#             "lng": -75.167346
#         },
#         "name": "Parkway Parking - Liberty Place 44 S 16th",
#         "place_id": "ChIJ-TYOMzDGxokR9-b8FZeIr7E",
#         "county": "Philadelphia County",
#         "no_of_cars": 16
#     },
#     {
#         "address": "1801 Howell Mill Rd NW, Atlanta, GA 30318, United States",
#         "location": {
#             "lat": 33.8040331,
#             "lng": -84.4125141
#         },
#         "name": "The District at Howell Mill",
#         "place_id": "ChIJy-H3HuIE9YgRkHpYTbWgSPk",
#         "county": "Fulton County",
#         "no_of_cars": 16
#     },
#     {
#         "address": "1250 Caroline St NE, Atlanta, GA 30307, United States",
#         "location": {
#             "lat": 33.7586144,
#             "lng": -84.3480019
#         },
#         "name": "Edgewood Retail District",
#         "place_id": "ChIJLyjqUbUG9YgRcFicU-t1ksg",
#         "county": "Fulton County",
#         "no_of_cars": 43
#     },
#     {
#         "address": "3480 Marketplace Blvd, East Point, GA 30344, United States",
#         "location": {
#             "lat": 33.6580831,
#             "lng": -84.5025423
#         },
#         "name": "Camp Creek Marketplace",
#         "place_id": "ChIJP-6cXBPi9IgRZQXB_35k45U",
#         "county": "Fulton County",
#         "no_of_cars": 35
#     },
#     {
#         "address": "1544 Piedmont Ave NE, Atlanta, GA 30324, United States",
#         "location": {
#             "lat": 33.7980584,
#             "lng": -84.3706535
#         },
#         "name": "Ansley Mall",
#         "place_id": "ChIJ5eKOEzQE9YgR4fvIuIdAo7k",
#         "county": "Fulton County",
#         "no_of_cars": 29
#     },
#     {
#         "address": "Pryor St @ Martin L King Jr Dr, 141 Pryor St SW, Atlanta, GA 30303, United States",
#         "location": {
#             "lat": 33.7514027,
#             "lng": -84.391302
#         },
#         "name": "Fulton County Government Center Bike Rack",
#         "place_id": "ChIJvdR_rk0D9YgRr_r1CJpe5kU",
#         "county": "Fulton County",
#         "no_of_cars": 15
#     },
#     {
#         "address": "2943 N Druid Hills Rd, Atlanta, GA 30329, United States",
#         "location": {
#             "lat": 33.8154232,
#             "lng": -84.3132036
#         },
#         "name": "Toco Hills Shopping Center",
#         "place_id": "ChIJJdymdkwG9YgRBsuzUiIb76s",
#         "county": "Fulton County",
#         "no_of_cars": 38
#     },
#     {
#         "address": "6365 Halcyon Way, Alpharetta, GA 30005, United States",
#         "location": {
#             "lat": 34.1107822,
#             "lng": -84.224291
#         },
#         "name": "Halcyon",
#         "place_id": "ChIJaYg_o7Sd9YgRF7lPleBTMjI",
#         "county": "Fulton County",
#         "no_of_cars": 21
#     },
#     {
#         "address": "4330 Peachtree Rd, Brookhaven, GA 30319, United States",
#         "location": {
#             "lat": 33.8701631,
#             "lng": -84.33673780000001
#         },
#         "name": "Town Brookhaven",
#         "place_id": "ChIJf0XnDcEI9YgRZvR0K86ti3I",
#         "county": "Fulton County",
#         "no_of_cars": 30
#     },
#     {
#         "address": "3495 Buckhead Loop NE, Atlanta, GA 30326, United States",
#         "location": {
#             "lat": 33.8502144,
#             "lng": -84.3703906
#         },
#         "name": "Buckhead Station",
#         "place_id": "ChIJL8bE3F4P9YgRIxvtXYNqY8s",
#         "county": "Fulton County",
#         "no_of_cars": 14
#     },
#     {
#         "address": "2345 Peachtree Rd ste 9, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8189705,
#             "lng": -84.38677179999999
#         },
#         "name": "High Country Outfitters",
#         "place_id": "ChIJT-xLpZcF9YgRMnUeX4nyaSg",
#         "county": "Fulton County",
#         "no_of_cars": 2
#     },
#     {
#         "address": "2200 Avalon Blvd, Alpharetta, GA 30009, United States",
#         "location": {
#             "lat": 34.0707877,
#             "lng": -84.27717
#         },
#         "name": "Avalon",
#         "place_id": "ChIJ--oMDYR19YgR1dmg9HxwAxk",
#         "county": "Fulton County",
#         "no_of_cars": 11
#     },
#     {
#         "address": "77 Paces Ferry Pl NW, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8409053,
#             "lng": -84.3813917
#         },
#         "name": "Buckhead Market Place",
#         "place_id": "ChIJDV8Fmo4F9YgRQwW6PAEko-w",
#         "county": "Fulton County",
#         "no_of_cars": 43
#     },
#     {
#         "address": "3906 Roswell Rd NE, Atlanta, GA 30342, United States",
#         "location": {
#             "lat": 33.8620231,
#             "lng": -84.3810211
#         },
#         "name": "High Country Outfitters",
#         "place_id": "ChIJEQPkz24P9YgRrcGXjWJpd1s",
#         "county": "Fulton County",
#         "no_of_cars": 27
#     },
#     {
#         "address": "593 Central Ave SW, Atlanta, GA 30312, United States",
#         "location": {
#             "lat": 33.738571,
#             "lng": -84.39375100000001
#         },
#         "name": "Juror parking YELLOW",
#         "place_id": "ChIJcyGqTIED9YgRB2gdFUWh0yI",
#         "county": "Fulton County",
#         "no_of_cars": 44
#     },
#     {
#         "address": "34 E Andrews Dr NW, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8433123,
#             "lng": -84.3803432
#         },
#         "name": "Patagonia",
#         "place_id": "ChIJofAU34sF9YgRTBhlnCX-DpI",
#         "county": "Fulton County",
#         "no_of_cars": 36
#     },
#     {
#         "address": "815 Sidney Marcus Blvd NE, Atlanta, GA 30324, United States",
#         "location": {
#             "lat": 33.8242679,
#             "lng": -84.3611202
#         },
#         "name": "The Dump Furniture Outlet",
#         "place_id": "ChIJP80fvecF9YgRPzBSzYd00Ls",
#         "county": "Fulton County",
#         "no_of_cars": 62
#     },
#     {
#         "address": "800 Peachtree St NE suite b&c, Atlanta, GA 30308, United States",
#         "location": {
#             "lat": 33.776664,
#             "lng": -84.3847404
#         },
#         "name": "Big Peach Ride + Run - Midtown",
#         "place_id": "ChIJodydlWgE9YgRENiIad_pGtc",
#         "county": "Fulton County",
#         "no_of_cars": 21
#     },
#     {
#         "address": "1530 Ellsworth Industrial Blvd NW, Atlanta, GA 30318, United States",
#         "location": {
#             "lat": 33.7969853,
#             "lng": -84.4274701
#         },
#         "name": "Westside Market Midtown",
#         "place_id": "ChIJncIiw9kE9YgRWud6aohjMU0",
#         "county": "Fulton County",
#         "no_of_cars": 20
#     },
#     {
#         "address": "56 E Andrews Dr NW, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8429372,
#             "lng": -84.38094950000001
#         },
#         "name": "Andrews Square",
#         "place_id": "ChIJqacMZ4kF9YgRfMYuYN9heEE",
#         "county": "Fulton County",
#         "no_of_cars": 49
#     },
#     {
#         "address": "Peachtree Corners, GA 30092, United States",
#         "location": {
#             "lat": 33.9799533,
#             "lng": -84.2145613
#         },
#         "name": "Peachtree Corners Town Center",
#         "place_id": "ChIJ9f99NaSh9YgRvd0epz5fzQs",
#         "county": "Fulton County",
#         "no_of_cars": 20
#     },
#     {
#         "address": "790 Huff Rd NW, Atlanta, GA 30318, United States",
#         "location": {
#             "lat": 33.7868764,
#             "lng": -84.4138878
#         },
#         "name": "Chattahoochee Coffee Company - Westside",
#         "place_id": "ChIJ7bJv2-sE9YgRP7VxaXU2HF4",
#         "county": "Fulton County",
#         "no_of_cars": 17
#     },
#     {
#         "address": "333 Nelson St SW, Atlanta, GA 30313, United States",
#         "location": {
#             "lat": 33.7515963,
#             "lng": -84.3987604
#         },
#         "name": "Castleberry Point Lofts",
#         "place_id": "ChIJs6EW73gD9YgRjwU0wxUoYPw",
#         "county": "Fulton County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "3423 Piedmont Rd NE #387, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8487034,
#             "lng": -84.3729158
#         },
#         "name": "Atlanta Tech Village Parking Garage",
#         "place_id": "ChIJN7DIpl8P9YgRhP3xeMyaKII",
#         "county": "Fulton County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "3365 Piedmont Rd NE #1400, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8463827,
#             "lng": -84.37245539999999
#         },
#         "name": "Roam Buckhead - Piedmont",
#         "place_id": "ChIJGeQ8gvUF9YgR3cA29obkSRY",
#         "county": "Fulton County",
#         "no_of_cars": 59
#     },
#     {
#         "address": "77 W Paces Ferry Rd NW, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8407325,
#             "lng": -84.3814773
#         },
#         "name": "Whole Foods Market",
#         "place_id": "ChIJQySAuI4F9YgRj3NAqVrX5js",
#         "county": "Fulton County",
#         "no_of_cars": 58
#     },
#     {
#         "address": "730 Peachtree St NE Suite 100, Atlanta, GA 30308, United States",
#         "location": {
#             "lat": 33.7743893,
#             "lng": -84.38490709999999
#         },
#         "name": "El Vi\u00f1edo Local",
#         "place_id": "ChIJ8-AgkXwF9YgRerw_Yj02Fsw",
#         "county": "Fulton County",
#         "no_of_cars": 7
#     },
#     {
#         "address": "1943 Peachtree Rd, Atlanta, GA 30309, United States",
#         "location": {
#             "lat": 33.8076108,
#             "lng": -84.3933433
#         },
#         "name": "Brookwood Village",
#         "place_id": "ChIJN3bFyqsF9YgRQ5LrWefE4yA",
#         "county": "Fulton County",
#         "no_of_cars": 14
#     },
#     {
#         "address": "22 14th St NW, Atlanta, GA 30309, United States",
#         "location": {
#             "lat": 33.7862472,
#             "lng": -84.38875569999999
#         },
#         "name": "Whole Foods Market",
#         "place_id": "ChIJ8xL51kwF9YgRrTycvSHW0AQ",
#         "county": "Fulton County",
#         "no_of_cars": 6
#     },
#     {
#         "address": "1235 Chattahoochee Ave NW #100, Atlanta, GA 30318, United States",
#         "location": {
#             "lat": 33.8015985,
#             "lng": -84.4286619
#         },
#         "name": "Ballard Designs Atlanta",
#         "place_id": "ChIJranMOd4E9YgRzORqPBYZC1g",
#         "county": "Fulton County",
#         "no_of_cars": 13
#     },
#     {
#         "address": "341 Marietta St NW, Atlanta, GA 30313, United States",
#         "location": {
#             "lat": 33.7624244,
#             "lng": -84.3965759
#         },
#         "name": "The Yard Milkshake Bar Atlanta - Centennial Park",
#         "place_id": "ChIJf037JNkF9YgRPe0jX-AokCw",
#         "county": "Fulton County",
#         "no_of_cars": 22
#     },
#     {
#         "address": "3210 Roswell Rd C1, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8425702,
#             "lng": -84.3794829
#         },
#         "name": "Smoke World Co. -Buckhead | CBD \u2022 Smoke & Vape |",
#         "place_id": "ChIJhZz8TjAF9YgREZ8oqw3khcI",
#         "county": "Fulton County",
#         "no_of_cars": 33
#     },
#     {
#         "address": "1060 Donald Lee Hollowell Pkwy NW, Atlanta, GA 30318, United States",
#         "location": {
#             "lat": 33.7727699,
#             "lng": -84.4228387
#         },
#         "name": "The Village Skatepark ATL",
#         "place_id": "ChIJKYqHQUIF9YgROsZfBEyrQhU",
#         "county": "Fulton County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "3475 Lenox Rd NE, Atlanta, GA 30326, United States",
#         "location": {
#             "lat": 33.849357,
#             "lng": -84.36083169999999
#         },
#         "name": "The Bucket Shop Cafe",
#         "place_id": "ChIJtYXlilYP9YgR2XzgD8zmewA",
#         "county": "Fulton County",
#         "no_of_cars": 8
#     },
#     {
#         "address": "5855 S Vickery St, Cumming, GA 30040, United States",
#         "location": {
#             "lat": 34.1828299,
#             "lng": -84.21930329999999
#         },
#         "name": "Vickery Village",
#         "place_id": "ChIJ8QHEGNCc9YgR6Bd-OzNVpQQ",
#         "county": "Fulton County",
#         "no_of_cars": 56
#     },
#     {
#         "address": "33 Peachtree Pl NE, Atlanta, GA 30309, United States",
#         "location": {
#             "lat": 33.7805675,
#             "lng": -84.3867313
#         },
#         "name": "Dancing Goats Midtown",
#         "place_id": "ChIJsZEJ9mcE9YgRDTcnhgVcVaI",
#         "county": "Fulton County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "3100 Sylvan Rd, Atlanta, GA 30354, United States",
#         "location": {
#             "lat": 33.6693501,
#             "lng": -84.41797509999999
#         },
#         "name": "Peachy Airport Parking",
#         "place_id": "ChIJ434Z7V_99IgRvUVFKeHlp_E",
#         "county": "Fulton County",
#         "no_of_cars": 299
#     },
#     {
#         "address": "1845 Piedmont Ave NE Ste 500, Atlanta, GA 30324, United States",
#         "location": {
#             "lat": 33.806807,
#             "lng": -84.36618659999999
#         },
#         "name": "Sprouts Farmers Market",
#         "place_id": "ChIJlxGwyM0F9YgRtcK7jFtCEog",
#         "county": "Fulton County",
#         "no_of_cars": 34
#     },
#     {
#         "address": "3520 Piedmont Rd NE #125, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8498664,
#             "lng": -84.3788654
#         },
#         "name": "Park Simple LLC",
#         "place_id": "ChIJ5eMvKUMF9YgRdN_CMBF84IY",
#         "county": "Fulton County",
#         "no_of_cars": 2
#     },
#     {
#         "address": "4120 Avalon Blvd, Alpharetta, GA 30009, United States",
#         "location": {
#             "lat": 34.0705109,
#             "lng": -84.27760169999999
#         },
#         "name": "High Country Outfitters",
#         "place_id": "ChIJvwh3HMV19YgRGlw7GiuKzG0",
#         "county": "Fulton County",
#         "no_of_cars": 38
#     },
#     {
#         "address": "3110 Roswell Rd NE, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.8402948,
#             "lng": -84.3796457
#         },
#         "name": "Buckhead Theatre",
#         "place_id": "ChIJZ6wEFowF9YgRgtnWhjolCJ8",
#         "county": "Fulton County",
#         "no_of_cars": 29
#     },
#     {
#         "address": "3400 Around Lenox Rd NE, Atlanta, GA 30326, United States",
#         "location": {
#             "lat": 33.8456966,
#             "lng": -84.36484709999999
#         },
#         "name": "Crate & Barrel",
#         "place_id": "ChIJTejS8PcF9YgRplToZBNIt98",
#         "county": "Fulton County",
#         "no_of_cars": 11
#     },
#     {
#         "address": "878 Peachtree St NE, Atlanta, GA 30309, United States",
#         "location": {
#             "lat": 33.7787492,
#             "lng": -84.384503
#         },
#         "name": "Blick Art Materials",
#         "place_id": "ChIJ6bk1aGgE9YgRvXaQns5Qbh4",
#         "county": "Fulton County",
#         "no_of_cars": 19
#     },
#     {
#         "address": "Atlanta, GA 30309, United States",
#         "location": {
#             "lat": 33.7811234,
#             "lng": -84.38634379999999
#         },
#         "name": "Midtown",
#         "place_id": "ChIJdym9WF0E9YgRMBWDOd-dwzU",
#         "county": "Fulton County",
#         "no_of_cars": 18
#     },
#     {
#         "address": "3275 Peachtree Rd, Atlanta, GA 30305, United States",
#         "location": {
#             "lat": 33.844417,
#             "lng": -84.3692028
#         },
#         "name": "Orvis",
#         "place_id": "ChIJ0eAiI4oF9YgRp8EzBA-RpRY",
#         "county": "Fulton County",
#         "no_of_cars": 22
#     },
#     {
# ...
#         "location": {
#             "lat": 41.2751077,
#             "lng": -75.89037069999999
#         },
#         "name": "Common Grounds Caffe",
#         "place_id": "ChIJ2wJFhQ8axYkRIm6NZwvY_Ms",
#         "county": "Luzerne County",
#         "no_of_cars": 24
#     },
#     {
#         "address": "32 Davis St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9573124,
#             "lng": -78.64421229999999
#         },
#         "name": "Arona Home Essentials Bradford",
#         "place_id": "ChIJi7BHojqAzYkRsWS9wpYeKqI",
#         "county": "McKean County",
#         "no_of_cars": 20
#     },
#     {
#         "address": "1001 E Main St Unit 17, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.979609,
#             "lng": -78.619035
#         },
#         "name": "Dunham's Sports",
#         "place_id": "ChIJcV5U1nuAzYkRlOca9ISPjpU",
#         "county": "McKean County",
#         "no_of_cars": 37
#     },
#     {
#         "address": "1001 E Main St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9811835,
#             "lng": -78.6193026
#         },
#         "name": "Big Lots",
#         "place_id": "ChIJgUl0gHyAzYkR6I2tP5QUMYw",
#         "county": "McKean County",
#         "no_of_cars": 28
#     },
#     {
#         "address": "250 Hemlock Ave, Kane, PA 16735, United States",
#         "location": {
#             "lat": 41.65463159999999,
#             "lng": -78.8038402
#         },
#         "name": "Kane Lumber & Fuel Co. True Value",
#         "place_id": "ChIJ07cBiwUNzYkRd7aBvaWFZIs",
#         "county": "McKean County",
#         "no_of_cars": 4
#     },
#     {
#         "address": "2932 Kings Run Rd, Shinglehouse, PA 16748, United States",
#         "location": {
#             "lat": 41.9949641,
#             "lng": -78.2712481
#         },
#         "name": "Canfield's Outdoor Power Equipment, Inc.",
#         "place_id": "ChIJrRhOTNYK0okR9bXOikFmrfI",
#         "county": "McKean County",
#         "no_of_cars": 2
#     },
#     {
#         "address": "296 Viaduct Rd, Mt Jewett, PA 16740, United States",
#         "location": {
#             "lat": 41.7597904,
#             "lng": -78.5871306
#         },
#         "name": "Kinzua Bridge State Park",
#         "place_id": "ChIJz1OQW5AyW4YRBO66GSMd8xU",
#         "county": "McKean County",
#         "no_of_cars": 13
#     },
#     {
#         "address": "1001 E Main St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.97831499999999,
#             "lng": -78.618907
#         },
#         "name": "Tractor Supply Co.",
#         "place_id": "ChIJ_zV0gHyAzYkR5KQ483v4FUk",
#         "county": "McKean County",
#         "no_of_cars": 28
#     },
#     {
#         "address": "120 Willow Run Dr, Kane, PA 16735, United States",
#         "location": {
#             "lat": 41.674829,
#             "lng": -78.82108989999999
#         },
#         "name": "CJ Spirits",
#         "place_id": "ChIJTU2nWkENzYkREUyhKD5UnTQ",
#         "county": "McKean County",
#         "no_of_cars": 1
#     },
#     {
#         "address": "2 Bolivar Dr, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9776913,
#             "lng": -78.61765749999999
#         },
#         "name": "Sheetz",
#         "place_id": "ChIJkcG_f3yAzYkRDWhZEV7YWAA",
#         "county": "McKean County",
#         "no_of_cars": 33
#     },
#     {
#         "address": "Forest Rd 454, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.8429276,
#             "lng": -78.9461297
#         },
#         "name": "Rimrock Overlook",
#         "place_id": "ChIJgVB5y75ozYkRNBSVCZ6DyUA",
#         "county": "McKean County",
#         "no_of_cars": 0
#     },
#     {
#         "address": "606 E Main St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.968885,
#             "lng": -78.6217573
#         },
#         "name": "NAPA Auto Parts - Barnhart-Davis Company",
#         "place_id": "ChIJexuaPWaAzYkRr97vkRzy2as",
#         "county": "McKean County",
#         "no_of_cars": 21
#     },
#     {
#         "address": "3014 US-219, Kane, PA 16735, United States",
#         "location": {
#             "lat": 41.7098574,
#             "lng": -78.6937736
#         },
#         "name": "Sheetz",
#         "place_id": "ChIJhTNOQDF1zYkRlWrIdlNnTc0",
#         "county": "McKean County",
#         "no_of_cars": 17
#     },
#     {
#         "address": "309 Flickerwood Rd, Kane, PA 16735, United States",
#         "location": {
#             "lat": 41.658558,
#             "lng": -78.779112
#         },
#         "name": "Flickerwood Wine Cellars and Cocktail Lounge",
#         "place_id": "ChIJO51gpe8MzYkRXPZfUTMvFLA",
#         "county": "McKean County",
#         "no_of_cars": 2
#     },
#     {
#         "address": "Smethport, PA 16749, United States",
#         "location": {
#             "lat": 41.809759,
#             "lng": -78.44672299999999
#         },
#         "name": "McKean Co Courthouse",
#         "place_id": "ChIJG3KeTSeQzYkRlVXymprVp0k",
#         "county": "McKean County",
#         "no_of_cars": 20
#     },
#     {
#         "address": "Bettum's Idlewood Family Campground, 299 Big Shanty Rd, Lewis Run, PA 16738, United States",
#         "location": {
#             "lat": 41.8020557,
#             "lng": -78.684359
#         },
#         "name": "Bettum's Idlewood Family Campground",
#         "place_id": "ChIJs_GB7vt3zYkRMTXN2Dn-KXw",
#         "county": "McKean County",
#         "no_of_cars": 0
#     },
#     {
#         "address": "300 Hackett Hollow, Smethport, PA 16749, United States",
#         "location": {
#             "lat": 41.8227496,
#             "lng": -78.4052457
#         },
#         "name": "Rainy Day Farm",
#         "place_id": "ChIJoUAAtz6OzYkRp6R0n4Nysoc",
#         "county": "McKean County",
#         "no_of_cars": 1
#     },
#     {
#         "address": "86 Elm St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.952463,
#             "lng": -78.64713189999999
#         },
#         "name": "Advance Auto Parts",
#         "place_id": "ChIJH5Hb_C2AzYkRD3XUryaPK60",
#         "county": "McKean County",
#         "no_of_cars": 14
#     },
#     {
#         "address": "109 Main St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9561908,
#             "lng": -78.6469549
#         },
#         "name": "Curaleaf PA Bradford",
#         "place_id": "ChIJ52TXj6mBzYkRkB0mcYBZPkU",
#         "county": "McKean County",
#         "no_of_cars": 21
#     },
#     {
#         "address": "104 Marvin St, Smethport, PA 16749, United States",
#         "location": {
#             "lat": 41.8059862,
#             "lng": -78.4524844
#         },
#         "name": "DG Market",
#         "place_id": "ChIJKfwP3SGQzYkR0dscPUrAEQc",
#         "county": "McKean County",
#         "no_of_cars": 3
#     },
#     {
#         "address": "32 Dustin Blvd, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.8590131,
#             "lng": -78.7871675
#         },
#         "name": "Kinzua East Kampground",
#         "place_id": "ChIJK3-aAGlxzYkRKpvM7gTj58c",
#         "county": "McKean County",
#         "no_of_cars": 2
#     },
#     {
#         "address": "50 Foster Brook Blvd, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9785336,
#             "lng": -78.60887939999999
#         },
#         "name": "Walmart Supercenter",
#         "place_id": "ChIJUUUaqn6AzYkRbYFy-3ZnLSY",
#         "county": "McKean County",
#         "no_of_cars": 9
#     },
#     {
#         "address": "50 Foster Brook Blvd, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9784309,
#             "lng": -78.60901679999999
#         },
#         "name": "Walmart Business Center",
#         "place_id": "ChIJRyPvUOGBzYkRPI8GlnS3XGQ",
#         "county": "McKean County",
#         "no_of_cars": 9
#     },
#     {
#         "address": "397 N Fraley St, Kane, PA 16735, United States",
#         "location": {
#             "lat": 41.6662726,
#             "lng": -78.81218919999999
#         },
#         "name": "Dollar General",
#         "place_id": "ChIJUQEWaRQNzYkRxjYq5RplB8s",
#         "county": "McKean County",
#         "no_of_cars": 21
#     },
#     {
#         "address": "141 Main St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9563865,
#             "lng": -78.64586059999999
#         },
#         "name": "McDonald's",
#         "place_id": "ChIJYQ0cti-AzYkRtHOdpa_awdI",
#         "county": "McKean County",
#         "no_of_cars": 22
#     },
#     {
#         "address": "1002 E Main St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9775496,
#             "lng": -78.6164398
#         },
#         "name": "Tim Hortons",
#         "place_id": "ChIJx14Qf3yAzYkRjJJyJ6JlKnY",
#         "county": "McKean County",
#         "no_of_cars": 37
#     },
#     {
#         "address": "2 Sharon Dr, McKean, PA 16426, United States",
#         "location": {
#             "lat": 42.0232141,
#             "lng": -80.1308968
#         },
#         "name": "Countryside Estates",
#         "place_id": "ChIJc_2_sLl9MogRG0fOUg2tKZ4",
#         "county": "McKean County",
#         "no_of_cars": 4
#     },
#     {
#         "address": "880 E Main St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9756176,
#             "lng": -78.616545
#         },
#         "name": "LUV Toyota Bradford",
#         "place_id": "ChIJ0ad2o3yAzYkR3WcchXPZH10",
#         "county": "McKean County",
#         "no_of_cars": 46
#     },
#     {
#         "address": "1034 E Main St, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.98046970000001,
#             "lng": -78.6167763
#         },
#         "name": "Dollar General",
#         "place_id": "ChIJp5j5-HuAzYkRczRS2_PWZSA",
#         "county": "McKean County",
#         "no_of_cars": 6
#     },
#     {
#         "address": "980 South Ave, Bradford, PA 16701, United States",
#         "location": {
#             "lat": 41.9053528,
#             "lng": -78.65244
#         },
#         "name": "Dollar General",
#         "place_id": "ChIJHcsvqt2DzYkRaYjnS_Im-do",
#         "county": "McKean County",
#         "no_of_cars": 6
#     },
#     {
#         "address": "397 E Clover Mill Rd, Exton, PA 19341, United States",
#         "location": {
#             "lat": 40.0183481,
#             "lng": -75.6387778
#         },
#         "name": "Exton Store-N-More",
#         "place_id": "ChIJkUXaCmH0xokRBb0Z-zTlKu0",
#         "county": "Chester County",
#         "no_of_cars": 8
#     },
#     {
#         "address": "25 Sharpless St, West Chester, PA 19382, United States",
#         "location": {
#             "lat": 39.9544967,
#             "lng": -75.6011475
#         },
#         "name": "Sharpless Garage",
#         "place_id": "ChIJqfIa_3PxxokRpCgWcXibpTY",
#         "county": "Chester County",
#         "no_of_cars": 22
#     },
#     {
#         "address": "Unnamed Road, 300 E Marshall St, West Chester, PA 19380, United States",
#         "location": {
#             "lat": 39.968634,
#             "lng": -75.60199399999999
#         },
#         "name": "Metropolitan West Chester Visitor Parking Lot",
#         "place_id": "ChIJs0n3F0_xxokRJ_ei8dDXf4E",
#         "county": "Chester County",
#         "no_of_cars": 13
#     },
#     {
#         "address": "499 W Washington St, West Chester, PA 19380, United States",
#         "location": {
#             "lat": 39.9588746,
#             "lng": -75.61408349999999
#         },
#         "name": "West End County Parking",
#         "place_id": "ChIJ5c0-fgDxxokR8f2vTCwy2yE",
#         "county": "Chester County",
#         "no_of_cars": 64
#     }
# ]
#                                               address  \
# 0   Parking lot, Water St, Clinton, NJ 08809, Unit...
# 1             NJ-31, Clinton, NJ 08809, United States
# 2   234 Main St, Hurleyville, NY 12747, United States
# 3   325 W Freedom Ave, Burnham, PA 17009, United S...
# 4    842 W 4th St, Lewistown, PA 17044, United States
# 5    7345 PA-655, Reedsville, PA 17084, United States
# 6    34 Morgan Dr, Mcveytown, PA 17051, United States
# 7   64 Forest Edge Ln, Lewistown, PA 17044, United...
# 8       5867 US-522, McClure, PA 17841, United States
# 9    150 Helen St, Lewistown, PA 17044, United States
# 10  20 Shaw Ave #6, Lewistown, PA 17044, United St...
# 11  100 Cherry St, Lewistown, PA 17044, United States
# 12  1146 Honey Creek Rd, Reedsville, PA 17084, Uni...
# 13  100 Classic Car Dr, Reedsville, PA 17084, Unit...
# 14  10180 U.S. 522 S, Lewistown, PA 17044, United ...
# 15   S Juniata St, Lewistown, PA 17044, United States
# 16  100 Cherry St, Lewistown, PA 17044, United States
# 17       900 Green Ln, Union, NJ 07083, United States
# 18                     Union, NJ 07083, United States
# 19                     Union, NJ 07083, United States
#
#                                              location  \
# 0             {'lat': 40.6387329, 'lng': -74.9117948}
# 1             {'lat': 40.6392178, 'lng': -74.8938984}
# 2             {'lat': 41.7371061, 'lng': -74.6734227}
# 3              {'lat': 40.6304321, 'lng': -77.573883}
# 4              {'lat': 40.591275, 'lng': -77.5948901}
# 5              {'lat': 40.6587312, 'lng': -77.622937}
# 6      {'lat': 40.4778482, 'lng': -77.77877459999999}
# 7             {'lat': 40.6364735, 'lng': -77.4779076}
# 8             {'lat': 40.6800825, 'lng': -77.4116385}
# 9             {'lat': 40.5883966, 'lng': -77.5798216}
# 10  {'lat': 40.60090599999999, 'lng': -77.56812289...
# 11     {'lat': 40.5979522, 'lng': -77.56532829999999}
# 12     {'lat': 40.6854246, 'lng': -77.55803039999999}
# 13            {'lat': 40.6971777, 'lng': -77.5936251}
# 14     {'lat': 40.5814965, 'lng': -77.61158999999999}
# 15            {'lat': 40.5954389, 'lng': -77.5759211}
# 16            {'lat': 40.5978752, 'lng': -77.5662241}
# 17     {'lat': 40.6826058, 'lng': -74.23897819999999}
# 18     {'lat': 40.6922395, 'lng': -74.28800369999999}
# 19            {'lat': 40.6893969, 'lng': -74.3027101}
#
#                                     name                     place_id  \
# 0                          Municipal Lot  ChIJR8IPtAWLw4kROvacIJ6onxQ
# 1                    Clinton Park & Ride  ChIJR8t_I3eLw4kRmJNbQ9Z1a4Q
# 2                        Morgan Outdoors  ChIJyZKFEAiZ3IkR0Y2NXWcrohQ
# 3                 Mifflin County Commons  ChIJ18GSIGK1zokROnth9b2MgbY
# 4                Dan Pierce Outdoor Shop  ChIJ53wMosJKyYkRSUmITaXRot4
# 5               Hostetler Country Market  ChIJQ-X_VUS1zokRenmiLUAVIH8
# 6               Nolt's Farm & Garden Inc  ChIJ_ePF83BQyYkRFrYOb2XmxT8
# 7                Carolus Trapping Supply  ChIJYT5tIK_LzokRDBwZ5PP8S5Q
# 8                            Point Store  ChIJ14epjXrOzokRArbqb-AIJ7w
# 9                      Lewistown Station  ChIJkY-F5ZVKyYkRCwmoQR7oFN8
# 10                        Park Way Store  ChIJned00a5KyYkRUfRFk2sUpbw
# 11                              Rec Park  ChIJy9kaLUVLyYkRXf6fRMmteJo
# 12  The Reedsville Creamery - Farm Stand  ChIJ7U17ta_LzokRObFoxlW_Fo8
# 13                 Top Flight Automotive  ChIJ75HUcia3zokRdlbGFkCCP6k
# 14                   Walmart Supercenter  ChIJg5ydPwNLyYkRwwO8lON2drA
# 15                           Parking Lot  ChIJTe8EdbtKyYkRPnu0P_k0I1Y
# 16                Rec Park Swimming Pool  ChIJJ0MAoqhKyYkRWtZgNXaOsC8
# 17                           SP+ Parking  ChIJWaba00Ktw4kRCQduFc-lLNw
# 18                           Parking lot  ChIJU2ZdOQCtw4kRdDNJzko5dtM
# 19                               Parking  ChIJI2evNyWtw4kRYnQXkuAJIbg
#
#              county  no_of_cars
# 0    Clinton County           7
# 1    Clinton County          15
# 2   Sullivan County           3
# 3    Mifflin County          54
# 4    Mifflin County          19
# 5    Mifflin County           3
# 6    Mifflin County           3
# 7    Mifflin County           0
# 8    Mifflin County           7
# 9    Mifflin County           9
# 10   Mifflin County          10
# 11   Mifflin County           0
# 12   Mifflin County           2
# 13   Mifflin County           3
# 14   Mifflin County           4
# 15   Mifflin County          11
# 16   Mifflin County           2
# 17     Union County          30
# 18     Union County          57
# 19     Union County          12
